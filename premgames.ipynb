# %% [markdown]
# <a href="https://colab.research.google.com/github/rishimanihar/predicting_prem_games/blob/main/premgames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col = 0)
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
matches.shape
# Out:
# (1389, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Brighton and Hove Albion    72
# Southampton                 72
# Tottenham Hotspur           71
# Manchester City             71
# Leeds United                71
# Wolverhampton Wanderers     71
# Arsenal                     71
# Crystal Palace              71
# Burnley                     71
# Chelsea                     70
# Aston Villa                 70
# Leicester City              70
# Everton                     70
# West Bromwich Albion        38
# Fulham                      38
# Liverpool                   38
# Sheffield United            38
# Brentford                   34
# Norwich City                33
# Watford                     33
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %%
matches["round"].value_counts()  #is 39, one less than because liverpool second season is missing, should be 40 because 20 teams * 2 seasons
# Out:
# round
# Matchweek 1     39
# Matchweek 2     39
# Matchweek 3     39
# Matchweek 4     39
# Matchweek 5     39
# Matchweek 6     39
# Matchweek 7     39
# Matchweek 8     39
# Matchweek 9     39
# Matchweek 10    39
# Matchweek 11    39
# Matchweek 12    39
# Matchweek 13    39
# Matchweek 14    39
# Matchweek 15    39
# Matchweek 16    39
# Matchweek 17    39
# Matchweek 19    39
# Matchweek 20    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 34    39
# Matchweek 29    39
# Matchweek 31    39
# Matchweek 26    39
# Matchweek 28    39
# Matchweek 32    39
# Matchweek 18    37
# Matchweek 21    37
# Matchweek 22    37
# Matchweek 27    37
# Matchweek 30    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes #converts venue from string to category to numeric
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# 1       Tottenham  ...    NaN  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2    Norwich City  ...    NaN  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3         Arsenal  ...    NaN  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4  Leicester City  ...    NaN  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6     Southampton  ...    NaN  16.0   1.0  15.7  1.0  0.0   0.0   2022
#
#               team  venue_code
# 1  Manchester City           0
# ...

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes #converts opponent to a code
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# 1       Tottenham  ...  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2    Norwich City  ...  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3         Arsenal  ...  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4  Leicester City  ...  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6     Southampton  ...  16.0   1.0  15.7  1.0  0.0   0.0   2022
#
#               team  venue_code  opp_code
# 1  Manchester City           0        18
# ...

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex = True).astype("int") #uses string replacement to remove the colon and minute from the time and only be left with hour as an int
#(in the str.replace function, the :.+ means remove any characters after the colon)
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...   sot  dist   fk   pk pkatt season             team  \
# 1       Tottenham  ...   4.0  16.9  1.0  0.0   0.0   2022  Manchester City
# 2    Norwich City  ...   4.0  17.3  1.0  0.0   0.0   2022  Manchester City
# 3         Arsenal  ...  10.0  14.3  0.0  0.0   0.0   2022  Manchester City
# 4  Leicester City  ...   8.0  14.0  0.0  0.0   0.0   2022  Manchester City
# 6     Southampton  ...   1.0  15.7  1.0  0.0   0.0   2022  Manchester City
#
#   venue_code  opp_code  hour
# ...

# %%
matches["day_code"] = matches["date"].dt.dayofweek #converts date to day of week numerically
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  dist   fk   pk  pkatt season             team  \
# 1       Tottenham  ...  16.9  1.0  0.0    0.0   2022  Manchester City
# 2    Norwich City  ...  17.3  1.0  0.0    0.0   2022  Manchester City
# 3         Arsenal  ...  14.3  0.0  0.0    0.0   2022  Manchester City
# 4  Leicester City  ...  14.0  0.0  0.0    0.0   2022  Manchester City
# 6     Southampton  ...  15.7  1.0  0.0    0.0   2022  Manchester City
#
#   venue_code opp_code  hour  day_code
# 1          0       18    16         6
# ...

# %%
matches["target"] = matches['result'].astype("category").cat.codes #converts loss to 1, draw to 0, and win to 2
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City          0
# 2    Norwich City  ...  1.0  0.0    0.0    2022  Manchester City          1
# 3         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City          1
# 4  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City          0
# 6     Southampton  ...  1.0  0.0    0.0    2022  Manchester City          1
#
#   opp_code hour  day_code  target
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 150, min_samples_split = 10, random_state = 42, class_weight = 'balanced')

# %%
train = matches[matches["date"] < "2022-01-01"]
test = matches[matches["date"] >= "2022-01-01"]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(class_weight='balanced', min_samples_split=10,
#                        n_estimators=150, random_state=42)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(test["target"],preds)
accuracy
# Out:
# 0.3829787234042553

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))

# %%
pd.crosstab(index=combined["actual"], columns = combined["prediction"])
# Out:
# prediction   0   1   2
# actual
# 0           18  15  23
# 1           46  50  23
# 2           37  30  40

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds, average = 'weighted')
# Out:
# 0.43396886109090604

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W  2.0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L  1.0
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W  4.0
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L  2.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  5.0
#
#      ga        opponent  ...   fk   pk  pkatt  season             team  \
# ...

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = "left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset= new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
# /tmp/ipython-input-1738758534.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...

# %%
print(matches_rolling.index.names)
# Out:
# ['team', None]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /tmp/ipython-input-4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling = matches_rolling.droplevel(0)
matches_rolling.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 6  2020-10-04  14:00  Premier League  Matchweek 4  Sun  Home      W  2.0  1.0
# 7  2020-10-17  17:30  Premier League  Matchweek 5  Sat  Away      L  0.0  1.0
# 9  2020-10-25  19:15  Premier League  Matchweek 6  Sun  Home      L  0.0  1.0
# 11 2020-11-01  16:30  Premier League  Matchweek 7  Sun  Away      W  1.0  0.0
# 13 2020-11-08  19:15  Premier League  Matchweek 8  Sun  Home      L  0.0  3.0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 6     Sheffield Utd  ...         6       2    2.000000    1.333333   7.666667
# 7   Manchester City  ...         5       1    1.666667    1.666667   5.333333
# 9    Leicester City  ...         6       1    1.000000    1.666667   7.000000
# 11   Manchester Utd  ...         6       2    0.666667    1.000000   9.666667
# 13      Aston Villa  ...         6       1    0.333333    0.666667   9.666667
#
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < "2022-01-01"]
    test = data[data["date"] >= "2022-01-01"]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted = preds), index = test.index)
    precision = precision_score(test["target"], preds, average="weighted")
    return combined, precision, preds

# %%
combined, precision, preds = make_predictions(matches_rolling, predictors + new_cols)
precision
combined
# Out:
#       actual  predicted
# 54         1          2
# 55         0          2
# 56         2          2
# 57         2          2
# 58         2          2
# ...      ...        ...
# 1312       2          1
# 1313       1          2
# 1314       2          1
# 1315       1          2
# 1316       1          1
#
# [282 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team","opponent", "result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 54         1          2 2022-01-01                  Arsenal  Manchester City
# 55         0          2 2022-01-23                  Arsenal          Burnley
# 56         2          2 2022-02-10                  Arsenal           Wolves
# 57         2          2 2022-02-19                  Arsenal        Brentford
# 58         2          2 2022-02-24                  Arsenal           Wolves
# ...      ...        ...        ...                      ...              ...
# 1312       2          1 2022-03-13  Wolverhampton Wanderers          Everton
# 1313       1          2 2022-03-18  Wolverhampton Wanderers     Leeds United
# 1314       2          1 2022-04-02  Wolverhampton Wanderers      Aston Villa
# 1315       1          2 2022-04-08  Wolverhampton Wanderers    Newcastle Utd
# 1316       1          1 2022-04-24  Wolverhampton Wanderers          Burnley
#
#      result
# 54        L
# 55        D
# ...

# %%
class MissingDict(dict):
  __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves",
    "Man City": "Manchester City",
    "Man United": "Manchester Utd",
    "Newcastle": "Newcastle Utd",
    "Leeds" : "Leeds United",
    "Leicester" : "Leicester City",
    "West Brom" : "West Bromwich Albion",
    "Norwich" : "Norwich City"
}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 54         1          2 2022-01-01                  Arsenal  Manchester City
# 55         0          2 2022-01-23                  Arsenal          Burnley
# 56         2          2 2022-02-10                  Arsenal           Wolves
# 57         2          2 2022-02-19                  Arsenal        Brentford
# 58         2          2 2022-02-24                  Arsenal           Wolves
# ...      ...        ...        ...                      ...              ...
# 1312       2          1 2022-03-13  Wolverhampton Wanderers          Everton
# 1313       1          2 2022-03-18  Wolverhampton Wanderers     Leeds United
# 1314       2          1 2022-04-02  Wolverhampton Wanderers      Aston Villa
# 1315       1          2 2022-04-08  Wolverhampton Wanderers    Newcastle Utd
# 1316       1          1 2022-04-24  Wolverhampton Wanderers          Burnley
#
#      result new_team
# 54        L  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on = ["date", "new_team"], right_on = ["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           1            2 2022-01-01                  Arsenal
# 1           0            2 2022-01-23                  Arsenal
# 2           2            2 2022-02-10                  Arsenal
# 3           2            2 2022-02-19                  Arsenal
# 4           2            2 2022-02-24                  Arsenal
# ..        ...          ...        ...                      ...
# 263         2            1 2022-03-13  Wolverhampton Wanderers
# 264         1            2 2022-03-18  Wolverhampton Wanderers
# 265         2            1 2022-04-02  Wolverhampton Wanderers
# 266         1            2 2022-04-08  Wolverhampton Wanderers
# 267         1            1 2022-04-24  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0    Manchester City        L    Arsenal         2            2
# 1            Burnley        D    Arsenal         0            1
# ...

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

labels = ["Draw", "Loss", "Win"]

cm = confusion_matrix(test["target"], preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title("Confusion Matrix")
plt.ylabel("Actual Outcome")
plt.xlabel("Predicted Outcome")
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(test["target"], preds, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#         Draw       0.17      0.14      0.16        56
#         Loss       0.44      0.45      0.44       119
#          Win       0.36      0.39      0.38       107
#
#     accuracy                           0.37       282
#    macro avg       0.33      0.33      0.33       282
# weighted avg       0.36      0.37      0.36       282

# %%
odds_df = pd.read_csv("E0 (2).csv")
odds_df = odds_df[["Date", "HomeTeam", "AwayTeam", "PSCH", "PSCD", "PSCA"]]
odds_df.columns = ["date", "home_team", "away_team", "home_odds", "draw_odds", "away_odds"]
odds_df["date"] = pd.to_datetime(odds_df["date"], format="%d/%m/%Y")
odds_df.head()
# Out:
#         date       home_team    away_team  home_odds  draw_odds  away_odds
# 0 2020-09-12          Fulham      Arsenal       5.48       3.98       1.69
# 1 2020-09-12  Crystal Palace  Southampton       3.09       3.27       2.54
# 2 2020-09-12       Liverpool        Leeds       1.28       6.34      11.38
# 3 2020-09-12        West Ham    Newcastle       2.04       3.59       3.92
# 4 2020-09-13       West Brom    Leicester       3.38       3.38       2.32

# %%
matches_rolling["team_std"] = matches_rolling["team"].map(mapping)
matches_rolling["opponent_std"] = matches_rolling["opponent"].map(mapping)
matches_rolling.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2020-10-04  14:00  Premier League  Matchweek 4  Sun  Home      W  2.0  1.0
# 1 2020-10-17  17:30  Premier League  Matchweek 5  Sat  Away      L  0.0  1.0
# 2 2020-10-25  19:15  Premier League  Matchweek 6  Sun  Home      L  0.0  1.0
# 3 2020-11-01  16:30  Premier League  Matchweek 7  Sun  Away      W  1.0  0.0
# 4 2020-11-08  19:15  Premier League  Matchweek 8  Sun  Home      L  0.0  3.0
#
#           opponent  ...  gf_rolling  ga_rolling  sh_rolling  sot_rolling  \
# 0    Sheffield Utd  ...    2.000000    1.333333    7.666667     3.666667
# 1  Manchester City  ...    1.666667    1.666667    5.333333     3.666667
# 2   Leicester City  ...    1.000000    1.666667    7.000000     3.666667
# 3   Manchester Utd  ...    0.666667    1.000000    9.666667     4.000000
# 4      Aston Villa  ...    0.333333    0.666667    9.666667     2.666667
#
# ...

# %%
odds_21_22 = pd.read_csv("E0 (1).csv")
odds_21_22 = odds_21_22[["Date", "HomeTeam", "AwayTeam", "PSCH", "PSCD", "PSCA"]]
odds_21_22.columns = ["date", "home_team", "away_team", "home_odds", "draw_odds", "away_odds"]
odds_21_22["date"] = pd.to_datetime(odds_21_22["date"], format="%d/%m/%Y")
odds_21_22.head()
# Out:
#         date   home_team       away_team  home_odds  draw_odds  away_odds
# 0 2021-08-13   Brentford         Arsenal       3.94       3.33       2.13
# 1 2021-08-14  Man United           Leeds       1.67       4.20       5.40
# 2 2021-08-14     Burnley        Brighton       3.27       3.14       2.51
# 3 2021-08-14     Chelsea  Crystal Palace       1.34       5.40      11.00
# 4 2021-08-14     Everton     Southampton       2.05       3.45       4.07

# %%
odds_df["home_team"] = odds_df["home_team"].map(mapping)
odds_df["away_team"] = odds_df["away_team"].map(mapping)

odds_21_22["home_team"] = odds_21_22["home_team"].map(mapping)
odds_21_22["away_team"] = odds_21_22["away_team"].map(mapping)

odds_21_22
# Out:
#           date        home_team       away_team  home_odds  draw_odds  \
# 0   2021-08-13        Brentford         Arsenal       3.94       3.33
# 1   2021-08-14   Manchester Utd    Leeds United       1.67       4.20
# 2   2021-08-14          Burnley        Brighton       3.27       3.14
# 3   2021-08-14          Chelsea  Crystal Palace       1.34       5.40
# 4   2021-08-14          Everton     Southampton       2.05       3.45
# ..         ...              ...             ...        ...        ...
# 375 2022-05-22   Crystal Palace  Manchester Utd       2.82       3.57
# 376 2022-05-22   Leicester City     Southampton       1.70       4.39
# 377 2022-05-22        Liverpool          Wolves       1.14       9.75
# 378 2022-05-22  Manchester City     Aston Villa       1.17       8.40
# 379 2022-05-22     Norwich City       Tottenham       9.82       5.51
#
#      away_odds
# 0         2.13
# 1         5.40
# 2         2.51
# 3        11.00
# 4         4.07
# ..         ...
# ...

# %%
all_odds_df = pd.concat([odds_df, odds_21_22], ignore_index=True)

# Merge the matches_rolling dataframe with the combined odds dataframe
merged_df = matches_rolling.merge(all_odds_df,
                                  left_on=["date", "team_std", "opponent_std"],
                                  right_on=["date", "home_team", "away_team"],
                                  how="left")

# Now repeat the merge for away matches to capture odds where the team_std was the away_team
merged_df = merged_df.merge(all_odds_df,
                              left_on=["date", "team_std", "opponent_std"],
                              right_on=["date", "away_team", "home_team"],
                              how="left",
                              suffixes=('', '_away_odds'))

# Combine the odds columns where they exist (handling NaN values from left joins)
merged_df['home_odds'] = merged_df['home_odds'].fillna(merged_df['home_odds_away_odds'])
merged_df['draw_odds'] = merged_df['draw_odds'].fillna(merged_df['draw_odds_away_odds'])
merged_df['away_odds'] = merged_df['away_odds'].fillna(merged_df['away_odds_away_odds'])

# Drop the duplicate odds columns and the extra team columns from the second merge
merged_df = merged_df.drop(columns=['home_odds_away_odds', 'draw_odds_away_odds', 'away_odds_away_odds', 'home_team_away_odds', 'away_team_away_odds'], errors='ignore')

merged_df.describe()
# Out:
#                                 date           gf           ga           xg  \
# count                           1317  1317.000000  1317.000000  1317.000000
# mean   2021-07-05 06:12:50.842824704     1.312832     1.353834     1.299924
# min              2020-10-03 00:00:00     0.000000     0.000000     0.000000
# 25%              2021-01-30 00:00:00     0.000000     0.000000     0.700000
# 50%              2021-05-18 00:00:00     1.000000     1.000000     1.200000
# 75%              2021-12-12 00:00:00     2.000000     2.000000     1.800000
# max              2022-04-25 00:00:00     9.000000     9.000000     4.600000
# std                              NaN     1.252691     1.273745     0.766079
#
#                xga         poss    attendance  notes           sh  \
# count  1317.000000  1317.000000    684.000000    0.0  1317.000000
# mean      1.332650    49.778284  36134.937135    NaN    12.186029
# min       0.000000    18.000000   2000.000000    NaN     0.000000
# ...

# %%
merged_df
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %%
merged_df = merged_df.dropna(subset=['home_odds', 'draw_odds', 'away_odds'])
merged_df.describe()
# Out:
#                                 date           gf           ga           xg  \
# count                           1282  1282.000000  1282.000000  1282.000000
# mean   2021-07-09 11:33:02.527301120     1.302652     1.375195     1.289626
# min              2020-10-03 00:00:00     0.000000     0.000000     0.000000
# 25%              2021-01-30 06:00:00     0.000000     0.000000     0.700000
# 50%              2021-05-19 00:00:00     1.000000     1.000000     1.200000
# 75%              2021-12-15 00:00:00     2.000000     2.000000     1.800000
# max              2022-04-25 00:00:00     9.000000     9.000000     4.600000
# std                              NaN     1.252187     1.279921     0.764152
#
#                xga         poss    attendance  notes           sh  \
# count  1282.000000  1282.000000    681.000000    0.0  1282.000000
# mean      1.346880    49.553042  36269.158590    NaN    12.133385
# min       0.000000    18.000000   2000.000000    NaN     0.000000
# ...

# %%
merged_df = merged_df.drop(["home_team","away_team"], axis = 1)
merged_df
# Out:
#            date   time            comp         round  day venue result   gf  \
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# 5    2020-11-22  16:30  Premier League   Matchweek 9  Sun  Away      D  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code",
              "gf_rolling", "ga_rolling", "sh_rolling", "sot_rolling", "dist_rolling", "fk_rolling", "pk_rolling", "pkatt_rolling",
              "home_odds", "draw_odds", "away_odds"]

# %%
combined, precision, preds  = make_predictions(merged_df, predictors)
precision
combined
# Out:
#       actual  predicted
# 54         1          2
# 55         0          2
# 56         2          1
# 57         2          2
# 58         2          2
# ...      ...        ...
# 1312       2          1
# 1313       1          2
# 1314       2          1
# 1315       1          2
# 1316       1          1
#
# [282 rows x 2 columns]

# %%
print(classification_report(test["target"], preds, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#         Draw       0.22      0.23      0.22        56
#         Loss       0.48      0.45      0.47       119
#          Win       0.40      0.41      0.41       107
#
#     accuracy                           0.39       282
#    macro avg       0.37      0.37      0.37       282
# weighted avg       0.40      0.39      0.40       282

# %%
cm = confusion_matrix(test["target"], preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title("Confusion Matrix")
plt.ylabel("Actual Outcome")
plt.xlabel("Predicted Outcome")
plt.show()

# %%
# Out:
# 0.39361702127659576
